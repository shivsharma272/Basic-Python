# %% [markdown]
# Basic

# %%
2+2

# %%
4-2

# %%
test=500

# %%
test

# %%
test1='shiv'

# %%
test1

# %%
type(test)

# %%
type(test1)

# %%
test1=2

# %%
test1

# %%
type(test1)

# %%
a=True

# %%
a

# %%
type(a)

# %%
b_1=False

# %%
b_1

# %%
type(b_1)

# %%
b='False'

# %%
b

# %%
a='true'

# %%
a

# %%
type(a)

# %%
a=5

# %%
b=a

# %%
a

# %%
b

# %%
id(a)

# %%
id(b)

# %%
b=10

# %%
id(b)

# %%
a=5
b=10
a
b

# %%
c=a+b
c

# %%
a=10
b=5
c=a-b
c

# %%
a='shiv'
b='s'
c=a + b
c

# %%
c=a +''+ b
c

# %%
c=a +' '+ b
c

# %%
1a

# %%
1a=5
